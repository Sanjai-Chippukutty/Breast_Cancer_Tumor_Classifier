# %% [markdown]
# ##  Streamlit App – Breast Cancer Tumor Classifier
#
# To make our machine learning model interactive and accessible, we deploy it using **Streamlit**, a lightweight web framework for Python. This app allows users to input tumor diagnostic features and get real-time predictions on whether the tumor is **benign** or **malignant**.
#
# ---
#
# ###  App Structure Overview
#
# 1. **Load pre-trained model and scaler** using `joblib`
# 2. **Create a web UI** with input fields for 10 diagnostic features
# 3. **Predict tumor type** based on user input and show result
# 4. **Deploy locally or on cloud (e.g., Streamlit Cloud, Heroku)**
#
# ---

# %%
import streamlit as st
import joblib
import numpy as np

# Load model and scaler
model = joblib.load("C:/Users/sanja/1. Breast_Cancer_Tumor_Classifier/1.Breast_Cancer_Tumor_Classifier/models/best_model.pkl")
scaler = joblib.load("C:/Users/sanja/1. Breast_Cancer_Tumor_Classifier/1.Breast_Cancer_Tumor_Classifier/models/scaler.pkl")

# Streamlit UI
st.set_page_config(page_title="Breast Cancer Tumor Classifier", layout="centered")

st.title(" Breast Cancer Tumor Classifier")
st.markdown("This app predicts whether a breast tumor is **benign** or **malignant** based on diagnostic features.")

# Input section
st.header("Enter Diagnostic Features")
features = [
    "radius_mean", "texture_mean", "perimeter_mean", "area_mean", "smoothness_mean",
    "compactness_mean", "concavity_mean", "concave_points_mean", "symmetry_mean", "fractal_dimension_mean"
]

input_data = []
for feature in features:
    value = st.number_input(f"{feature.replace('_', ' ').capitalize()}:", min_value=0.0, step=0.1)
    input_data.append(value)

# Prediction
if st.button("Predict Tumor Type"):
    try:
        X = np.array(input_data).reshape(1, -1)
        X_scaled = scaler.transform(X)
        prediction = model.predict(X_scaled)[0]

        if prediction == 1:
            st.error(" The tumor is predicted to be **Malignant**.")
        else:
            st.success(" The tumor is predicted to be **Benign**.")
    except Exception as e:
        st.warning(f" Error during prediction: {e}")
# Out:
# 2025-07-28 11:49:49.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.900 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-28 11:49:49.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
